# %%
import pandas as pd
df_movies = pd.read_csv('C:\\Users\\Heenashree_Khandelwa\\PycharmProjects\\Analytics_MovieLens\\MovieLens\\ml-latest-small\\movies.csv')
df_ratings = pd.read_csv('C:\\Users\\Heenashree_Khandelwa\\PycharmProjects\\Analytics_MovieLens\\MovieLens\\ml-latest-small\\ratings.csv')

# %%
df_movies
# Out:
#       movieId                                              title  \
# 0           1                                   Toy Story (1995)
# 1           2                                     Jumanji (1995)
# 2           3                            Grumpier Old Men (1995)
# 3           4                           Waiting to Exhale (1995)
# 4           5                 Father of the Bride Part II (1995)
# 5           6                                        Heat (1995)
# 6           7                                     Sabrina (1995)
# 7           8                                Tom and Huck (1995)
# 8           9                                Sudden Death (1995)
# 9          10                                   GoldenEye (1995)
# 10         11                     American President, The (1995)
# 11         12                 Dracula: Dead and Loving It (1995)
# 12         13                                       Balto (1995)
# ...

# %%
df_ratings
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# 5            1       70     3.0   964982400
# 6            1      101     5.0   964980868
# 7            1      110     4.0   964982176
# 8            1      151     5.0   964984041
# 9            1      157     5.0   964984100
# 10           1      163     5.0   964983650
# 11           1      216     5.0   964981208
# 12           1      223     3.0   964980985
# 13           1      231     5.0   964981179
# 14           1      235     4.0   964980908
# 15           1      260     5.0   964981680
# 16           1      296     3.0   964982967
# 17           1      316     3.0   964982310
# 18           1      333     5.0   964981179
# 19           1      349     4.0   964982563
# ...

# %%
df_ratings.head(10)
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931
# 5       1       70     3.0  964982400
# 6       1      101     5.0  964980868
# 7       1      110     4.0  964982176
# 8       1      151     5.0  964984041
# 9       1      157     5.0  964984100

# %%
df_movies.head(5)
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
df_movies.isnull().any()
# Out:
# movieId    False
# title      False
# genres     False
# dtype: bool

# %%
df_movies[['title']]
# Out:
#                                                   title
# 0                                      Toy Story (1995)
# 1                                        Jumanji (1995)
# 2                               Grumpier Old Men (1995)
# 3                              Waiting to Exhale (1995)
# 4                    Father of the Bride Part II (1995)
# 5                                           Heat (1995)
# 6                                        Sabrina (1995)
# 7                                   Tom and Huck (1995)
# 8                                   Sudden Death (1995)
# 9                                      GoldenEye (1995)
# 10                       American President, The (1995)
# 11                   Dracula: Dead and Loving It (1995)
# 12                                         Balto (1995)
# 13                                         Nixon (1995)
# 14                              Cutthroat Island (1995)
# 15                                        Casino (1995)
# ...

# %%
df_ratings[['rating']].describe()
# Out:
#               rating
# count  100836.000000
# mean        3.501557
# std         1.042529
# min         0.500000
# 25%         3.000000
# 50%         3.500000
# 75%         4.000000
# max         5.000000

# %%
df_ratings[df_ratings.rating>4.0]
# Out:
#         userId  movieId  rating   timestamp
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# 6            1      101     5.0   964980868
# 8            1      151     5.0   964984041
# 9            1      157     5.0   964984100
# 10           1      163     5.0   964983650
# 11           1      216     5.0   964981208
# 13           1      231     5.0   964981179
# 15           1      260     5.0   964981680
# 18           1      333     5.0   964981179
# 21           1      362     5.0   964982588
# 25           1      457     5.0   964981909
# 28           1      527     5.0   964984002
# 31           1      553     5.0   964984153
# 35           1      596     5.0   964982838
# 36           1      608     5.0   964982931
# 38           1      661     5.0   964982838
# 44           1      919     5.0   964982475
# 45           1      923     5.0   964981529
# 46           1      940     5.0   964982176
# ...

# %%
#change index

# %%
df_movies.index
# Out:
# RangeIndex(start=0, stop=9742, step=1)

# %%
#df_movies.set_index('movieId') #this has changed the datset now
df_movies.head(10)
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
# 5        6                         Heat (1995)
# 6        7                      Sabrina (1995)
# 7        8                 Tom and Huck (1995)
# 8        9                 Sudden Death (1995)
# 9       10                    GoldenEye (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
# 5                        Action|Crime|Thriller
# 6                               Comedy|Romance
# 7                           Adventure|Children
# ...

# %%
df_movies.loc[6] # this will give information based on row
# Out:
# movieId                 7
# title      Sabrina (1995)
# genres     Comedy|Romance
# Name: 6, dtype: object

# %%
df_movies.iloc[3][1]
# Out:
# 'Waiting to Exhale (1995)'
