# %%
Pandas is the most popular python library that is used for data analysis. 
It provides highly optimized performance with back-end source code is purely written in C or Python.
It is an opensource library that allows to you perform data manipulation in Python. 
Pandas library is built on top of Numpy, meaning Pandas needs Numpy to operate. 
Pandas provide an easy way to create, manipulate and wrangle the data. Pandas is also an elegant solution for time series data.



Best way to Install

1. conda install pandas
2. pip install pandas

We can analyze data in pandas with:

1. Series
2. DataFrames

Series:
Series is one dimensional(1-D) array defined in pandas that can be used to store any data type.
  
Data: 
A Scalar value which can be integerValue, string
A Python Dictionary which can be Key, Value pair
A Ndarray
Note: Index by default is from 0, 1, 2, …(n-1) where n is length of data.

# %%
########################### Series #########################################

import pandas as pd
 
# a simple list
list = ['g','e','e','k','s','f', 'o','r','g','e','e','k','s']
  
# create series form a list
ser = pd.Series(list)
ser
# Out:
# 0     g
# 1     e
# 2     e
# 3     k
# 4     s
# 5     f
# 6     o
# 7     r
# 8     g
# 9     e
# 10    e
# 11    k
# 12    s
# dtype: object

# %%
#setting the index
ser = pd.Series(list,index=[10,11,12,13,14,15,16,70,80,19,20,21,22])
# accessing a element using index element
print(ser)
# Out:
# 10    g
# 11    e
# 12    e
# 13    k
# 14    s
# 15    f
# 16    o
# 70    r
# 80    g
# 19    e
# 20    e
# 21    k
# 22    s
# dtype: object

# %%
df = pd.read_csv("C:\\Users\\Heenashree_Khandelwa\\PycharmProjects\\Analytics_MovieLens\\MovieLens\\stock_data.csv")
df
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82     87.0   845     larry page
# 1     WMT           4.61    484.0    65           n.a.
# 2    MSFT             -1     85.0    64     bill gates
# 3    RIL   not available     50.0  1023  mukesh ambani
# 4    TATA            5.6     -1.0  n.a.     ratan tata
# 5    Ford            NaN      NaN   NaN           Ford

# %%
df['tickers']
# Out:
# 0    GOOGL
# 1      WMT
# 2     MSFT
# 3     RIL
# 4     TATA
# 5     Ford
# Name: tickers, dtype: object

# %%
df['revenue']
# Out:
# 0     87.0
# 1    484.0
# 2     85.0
# 3     50.0
# 4     -1.0
# 5      NaN
# Name: revenue, dtype: float64

# %%
#Create dataframe
matrix_data = np.random.randint(1,10,size=20).reshape(5,4)
row_labels = ['A','B','C','D','E']
column_headings = ['W','X','Y','Z']
import pandas as pd
df1 = pd.DataFrame(data=matrix_data, index=row_labels, columns=column_headings)
df1
# Out:
#    W  X  Y  Z
# A  4  2  3  4
# B  4  6  2  2
# C  1  5  3  5
# D  1  7  1  6
# E  2  7  6  6

# %%
d={'a':[10,20],'b':[30,40],'c':[50,60]}

# %%
df = pd.DataFrame(d)
df
# Out:
#     a   b   c
# 0  10  30  50
# 1  20  40  60

# %%
#indexing and slicing
#DOT method
#Bracket method
matrix_data = np.random.randint(1,100,100).reshape(25,4)

column_headings = ['W','X','Y','Z']

df = pd.DataFrame(data=matrix_data,columns=column_headings)
df.head(2)
# Out:
#     W   X   Y   Z
# 0   7  45  99  50
# 1  71  63  97   6

# %%
df['X']
# Out:
# 0     45
# 1     63
# 2     69
# 3     69
# 4     36
# 5     43
# 6     66
# 7     26
# 8     48
# 9      6
# 10    43
# 11    84
# 12    74
# 13    92
# 14    71
# 15    24
# 16     2
# 17    15
# 18    21
# 19    37
# 20     5
# 21    90
# 22    22
# 23    31
# 24     3
# Name: X, dtype: int32

# %%
#Label-based 'loc' method
#Index based 'iloc' method
df1.loc['C']
# Out:
# W    1
# X    5
# Y    3
# Z    5
# Name: C, dtype: int32

# %%
df1.loc[['B','C']]
# Out:
#    W  X  Y  Z
# B  4  6  2  2
# C  1  5  3  5

# %%
df1.iloc[2]
# Out:
# W    1
# X    5
# Y    3
# Z    5
# Name: C, dtype: int32

# %%
df1.iloc[[1,3]]
# Out:
#    W  X  Y  Z
# B  4  6  2  2
# D  1  7  1  6

# %%
#Add new columns
df1['New'] = df1['X'] +df1['Y']
df1['New']
df1
# Out:
#    W  X  Y  Z  New
# A  4  2  3  4    5
# B  4  6  2  2    8
# C  1  5  3  5    8
# D  1  7  1  6    8
# E  2  7  6  6   13

# %%
#drop a row
df1.drop('A')
# Out:
#    W  X  Y  Z  New
# B  4  6  2  2    8
# C  1  5  3  5    8
# D  1  7  1  6    8
# E  2  7  6  6   13

# %%
df1
# Out:
#    W  X  Y  Z  New
# A  4  2  3  4    5
# B  4  6  2  2    8
# C  1  5  3  5    8
# D  1  7  1  6    8
# E  2  7  6  6   13

# %%
#Dropping doesnt make change to original DF. To make changes, use inplace=True
df1.drop('B', axis=0, inplace=True)
df1
# Out:
#    W  X  Z  New
# C  1  5  5    8
# D  1  7  6    8
# E  2  7  6   13

# %%
#MATPLOTLIB
people = ['Ann','Brandon','Chen','David','Emily','Farook',

'Gagan','Hamish','Imran','Joseph','Katherine','Lily']

age = [21,12,32,45,37,18,28,52,5,40,48,15]

weight = [55,35,77,68,70,60,72,69,18,65,82,48]

height = [160,135,170,165,173,168,175,159,105,171,155,158]

# %%
import matplotlib.pyplot as plt
plt.scatter(age,weight)

# %%
plt.figure(figsize=(8,6))
plt.title("PLot of Age vs Weight(in kgs)", fontsize=20)
plt.xlabel("Age(years)", fontsize=16)
plt.ylabel("Weight(kgs)", fontsize=16)
plt.grid(True)
plt.ylim(0,100)
plt.xticks([i*5 for i in range(12)], fontsize=15)
plt.yticks(fontsize=15)
plt.scatter(x=age, y=weight,c='orange',s=150, edgecolors='k')
plt.text(x=20,y=85,s="Weights after 18-20 years of age", fontsize=15)
plt.vlines(x=20,ymin=0,ymax=80,linestyles='dashed',color='blue',lw=3)

plt.legend(['Weight in kgs'],loc=2,fontsize=12)

plt.show()

# %%
'''
Mean: Mean is the sum of all values divided by the total number of values.

Median: The median is the middle value. It is the value that splits the dataset in half. To find the median, order your data from smallest to largest, and then find the data point that has an equal amount of values above it and below it.

Mode: The mode is the value that occurs the most frequently in your dataset. On a bar chart, the mode is the highest bar.

Variance: This is the most common measure of spread. Variance is the average of the squares of the deviations from the mean. Squaring the deviations ensures that negative and positive deviations do not cancel each other out.

Standard Deviation: Because variance is produced by squaring the distance from the mean, its unit does not match that of the original data. Standard deviation is a mathematical trick to bring back the parity. It is the positive square root of the variance.

'''

# %%
x = 50+50*np.random.random(size=15)
# Out:
# array([1.74513728e+01, 3.24659746e-02, 2.38672646e+01, 4.43287254e+01,
#        2.38923125e+01, 4.58290056e+01, 3.66939497e+00, 1.27615816e+01,
#        3.86786253e+01, 4.59978641e+01, 4.46252209e+01, 1.39541945e+01,
#        1.54902784e+01, 3.32444991e+01, 3.91218480e+01])

# %%
data = pd.read_csv('Boston.csv')
df = pd.DataFrame(data)
df.head(3)
# Out:
#    Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0           1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1           2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2           3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
#
#    tax  ptratio   black  lstat  medv
# 0  296     15.3  396.90   4.98  24.0
# 1  242     17.8  396.90   9.14  21.6
# 2  242     17.8  392.83   4.03  34.7

# %%
df[['crim','zn','indus']].head(10)
# Out:
#       crim    zn  indus
# 0  0.00632  18.0   2.31
# 1  0.02731   0.0   7.07
# 2  0.02729   0.0   7.07
# 3  0.03237   0.0   2.18
# 4  0.06905   0.0   2.18
# 5  0.02985   0.0   2.18
# 6  0.08829  12.5   7.87
# 7  0.14455  12.5   7.87
# 8  0.21124  12.5   7.87
# 9  0.17004  12.5   7.87

# %%
from matplotlib import pyplot as plt

#Number od records in csv
df.shape
# Out:
# (506, 15)

# %%
for c in df.columns:
    plt.title("Plot of "+c,fontsize=15)
    plt.hist(df[c],bins=20)
    plt.show()

# %%
import pandas as pd
lf = pd.read_excel('Sample - Superstore.xls')

# %%
lf.head(10)
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 5       6  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 6       7  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 7       8  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 8       9  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 9      10  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
#
#      Customer Name    Segment        Country             City  ...  \
# ...

# %%
#lf.drop("Row ID", axis=1, inplace=True)
lf.head(10)
# Out:
#          Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 5  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 6  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 7  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 8  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 9  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# ...

# %%
#if we are only intereseted in few rows or columns in the dataset, we can use loc
#We need to pass on two arguments to the loc method – one for indicating the rows, and another for indicating the columns. These should be Python lists.

lf.iloc[[5,6,7]]
# Out:
#          Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 5  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 6  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 7  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
#
#      Customer Name   Segment        Country         City       State  \
# 5  Brosina Hoffman  Consumer  United States  Los Angeles  California
# 6  Brosina Hoffman  Consumer  United States  Los Angeles  California
# 7  Brosina Hoffman  Consumer  United States  Los Angeles  California
#
#    Postal Code Region       Product ID         Category Sub-Category  \
# 5        90032   West  FUR-FU-10001487        Furniture  Furnishings
# 6        90032   West  OFF-AR-10002833  Office Supplies          Art
# 7        90032   West  TEC-PH-10002275       Technology       Phones
#
#                                         Product Name    Sales  Quantity  \
# ...

# %%
lf.loc[3:10,['Order ID', 'Order Date', 'Ship Date']]
# Out:
#           Order ID Order Date  Ship Date
# 3   US-2015-108966 2015-10-11 2015-10-18
# 4   US-2015-108966 2015-10-11 2015-10-18
# 5   CA-2014-115812 2014-06-09 2014-06-14
# 6   CA-2014-115812 2014-06-09 2014-06-14
# 7   CA-2014-115812 2014-06-09 2014-06-14
# 8   CA-2014-115812 2014-06-09 2014-06-14
# 9   CA-2014-115812 2014-06-09 2014-06-14
# 10  CA-2014-115812 2014-06-09 2014-06-14

# %%
#Suppose we want to calculate descriptive statistics (mean, median, standard deviation, and so on) of records 100-199 for sales and profit. 
#This is how subsetting helps us to achieve that:
data=lf.loc[[i for i in range(100,200)], ['Sales', 'Profit']]
data.describe()
# Out:
#              Sales       Profit
# count   100.000000   100.000000
# mean    262.957220     0.347574
# std     858.983762   170.744869
# min       1.788000 -1359.992000
# 25%      21.327000     1.635900
# 50%      66.960000     9.653600
# 75%     177.095000    23.458800
# max    8159.952000   585.552000
